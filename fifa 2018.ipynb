# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
df = pd.read_csv('C:\\Users\AHMED\Downloads\Compressed\complete-fifa-2017-player-dataset-global\FullData.csv')

# %%
df.head(10)
# Out:
#                  Name Nationality National_Position  National_Kit  \
# 0   Cristiano Ronaldo    Portugal                LS           7.0
# 1        Lionel Messi   Argentina                RW          10.0
# 2              Neymar      Brazil                LW          10.0
# 3         Luis Suárez     Uruguay                LS           9.0
# 4        Manuel Neuer     Germany                GK           1.0
# 5              De Gea       Spain                GK           1.0
# 6  Robert Lewandowski      Poland                LS           9.0
# 7         Gareth Bale       Wales                RS          11.0
# 8  Zlatan Ibrahimović      Sweden               NaN           NaN
# 9    Thibaut Courtois     Belgium                GK           1.0
#
#              Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  \
# 0     Real Madrid            LW       7.0   07/01/2009           2021.0
# 1    FC Barcelona            RW      10.0   07/01/2004           2018.0
# ...

# %%
del df['National_Kit'] #deletes the column National_Kit
df.head()
# Out:
#                 Name Nationality National_Position          Club  \
# 0  Cristiano Ronaldo    Portugal                LS   Real Madrid
# 1       Lionel Messi   Argentina                RW  FC Barcelona
# 2             Neymar      Brazil                LW  FC Barcelona
# 3        Luis Suárez     Uruguay                LS  FC Barcelona
# 4       Manuel Neuer     Germany                GK     FC Bayern
#
#   Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  Height  \
# 0            LW       7.0   07/01/2009           2021.0      94  185 cm
# 1            RW      10.0   07/01/2004           2018.0      93  170 cm
# 2            LW      11.0   07/01/2013           2021.0      92  174 cm
# 3            ST       9.0   07/11/2014           2021.0      92  182 cm
# 4            GK       1.0   07/01/2011           2021.0      92  193 cm
#
#       ...      Long_Shots Curve Freekick_Accuracy  Penalties Volleys  \
# ...

# %%
 plt.figure(figsize=(15,32))
sns.countplot(y = df.Nationality)

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Age",data=df)

# %% [markdown]
# # best players

# %%
#weights
a = 0.5
b = 1
c = 2
d = 3

# %% [markdown]
# ## best goal keeper

# %%
 
#GoalKeeping Characterstics
df['gk_Shot_Stopper'] = (b*df.Reactions + b*df.Composure + a*df.Speed + a*df.Strength + c*df.Jumping + b*df.GK_Positioning + c*df.GK_Diving + d*df.GK_Reflexes + b*df.GK_Handling)
df['gk_Sweeper'] = (b*df.Reactions + b*df.Composure + b*df.Speed + a*df.Short_Pass + a*df.Long_Pass + b*df.Jumping + b*df.GK_Positioning + b*df.GK_Diving + d*df.GK_Reflexes + b*df.GK_Handling + d*df.GK_Kicking + c*df.Vision)

# %%
df.head()
# Out:
#                 Name Nationality National_Position          Club  \
# 0  Cristiano Ronaldo    Portugal                LS   Real Madrid
# 1       Lionel Messi   Argentina                RW  FC Barcelona
# 2             Neymar      Brazil                LW  FC Barcelona
# 3        Luis Suárez     Uruguay                LS  FC Barcelona
# 4       Manuel Neuer     Germany                GK     FC Bayern
#
#   Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  Height  \
# 0            LW       7.0   07/01/2009           2021.0      94  185 cm
# 1            RW      10.0   07/01/2004           2018.0      93  170 cm
# 2            LW      11.0   07/01/2013           2021.0      92  174 cm
# 3            ST       9.0   07/11/2014           2021.0      92  182 cm
# 4            GK       1.0   07/01/2011           2021.0      92  193 cm
#
#       ...     Freekick_Accuracy Penalties Volleys  GK_Positioning GK_Diving  \
# ...

# %%
plt.figure(figsize=(10,5))
 
# Generate sequential data and plot
sd = df.sort_values('gk_Shot_Stopper', ascending=False)[:5]
x1 = np.array(list(sd['Name']))
y1 = np.array(list(sd['gk_Shot_Stopper']))
sns.barplot(x1,y1, palette=sns.color_palette("Reds_d"))
plt.ylabel("Shot Stopping Score")
# Out:
# Text(0,0.5,'Shot Stopping Score')

# %% [markdown]
# ## so th best goal keeper is
# # --- ( Manuel Neuer ) ---
# ===========================================================================================================================

# %% [markdown]
# # The Best Defenders

# %%
#Choosing Defenders
df['df_centre_backs'] = ( d*df.Reactions + c*df.Interceptions + d*df.Sliding_Tackle + d*df.Standing_Tackle + b*df.Vision+ b*df.Composure + b*df.Crossing +a*df.Short_Pass + b*df.Long_Pass+ c*df.Acceleration + b*df.Speed + d*df.Stamina + d*df.Jumping + d*df.Heading + b*df.Long_Shots + d*df.Marking + c*df.Aggression)
df['df_Wing_Backs'] = (b*df.Ball_Control + a*df.Dribbling + a*df.Marking + d*df.Sliding_Tackle + d*df.Standing_Tackle + a*df.Attacking_Position + c*df.Vision + c*df.Crossing + b*df.Short_Pass + c*df.Long_Pass + d*df.Acceleration +d*df.Speed + c*df.Stamina + a*df.Finishing)

# %% [markdown]
# ## first let's find the best left center back

# %%
plt.figure(figsize=(10,5))
sd = df[(df['Club_Position'] == 'LCB')].sort_values('df_centre_backs', ascending=False)[:5]
x2 = np.array(list(sd['Name']))
y2 = np.array(list(sd['df_centre_backs']))
sns.barplot(x2, y2, palette=sns.color_palette("Blues_d"))
plt.ylabel("LCB Score")
# Out:
# Text(0,0.5,'LCB Score')

# %% [markdown]
# ##   the Best Left Central Defender :-
# # --- ( Sergio ramos ) ---
#  =========================================================================================================================

# %% [markdown]
# ## now let's find the best left center back

# %%
plt.figure(figsize=(10,5))
 
sd = df[(df['Club_Position'] == 'RCB')].sort_values('df_centre_backs', ascending=False)[:5]
x2 = np.array(list(sd['Name']))
y2 = np.array(list(sd['df_centre_backs']))
sns.barplot(x2, y2, palette=sns.color_palette("Blues_d"))
plt.ylabel("RCB Score")
# Out:
# Text(0,0.5,'RCB Score')

# %% [markdown]
# ##   the Best Left Central Defender :-
# # --- ( Azpilicueta ) ---
#  =========================================================================================================================

# %% [markdown]
# ## now let's find the best wing back

# %%
plt.figure(figsize=(10,5))
 
sd = df[(df['Club_Position'] == 'LWB') | (df['Club_Position'] == 'LB')].sort_values('df_Wing_Backs', ascending=False)[:5]
x4 = np.array(list(sd['Name']))
y4 = np.array(list(sd['df_Wing_Backs']))
sns.barplot(x4, y4, palette=sns.color_palette("Blues_d"))
plt.ylabel("Left Back Score")
# Out:
# Text(0,0.5,'Left Back Score')

# %% [markdown]
# ##   the Best left wing back  :-
# # --- ( David Alaba ) ---
#  =========================================================================================================================

# %% [markdown]
# ## now let's right the best wing back

# %%
plt.figure(figsize=(10,5))
sd = df[(df['Club_Position'] == 'RWB') | (df['Club_Position'] == 'RB')].sort_values('df_Wing_Backs', ascending=False)[:5]
x5 = np.array(list(sd['Name']))
y5 = np.array(list(sd['df_Wing_Backs']))
sns.barplot(x5, y5, palette=sns.color_palette("Blues_d"))
plt.ylabel("Right Back Score")
# Out:
# Text(0,0.5,'Right Back Score')

# %% [markdown]
# ##   the Best right wing back  :-
# # --- (  Kyle Walker ) ---
#  =========================================================================================================================
